# %% [markdown]
# # cyBERT: a flexible log parser based on the BERT language model
#
# ## Table of Contents
# * Introduction
# * Download cyBERT Apache model from HuggingFace
# * Load model into cyBERT
# * Download a sample of Apache logs
# * Parse raw log data with cyBERT
#
# ## Introduction
#
# One of the most arduous tasks of any security operation (and equally as time consuming for a data scientist) is ETL and parsing. This notebook illustrates the simple steps to parse a sample of Apache log data using cyBERT.

# %%
import cudf
import s3fs
from os import path

from clx.analytics.cybert import Cybert

# %%
CLX_S3_BASE_PATH = "rapidsai-data/cyber/clx"
HF_S3_BASE_PATH = "models.huggingface.co/bert/raykallen/cybert_apache_parser"

CONFIG_FILENAME = "config.json"
MODEL_FILENAME = "pytorch_model.bin"
APACHE_SAMPLE_CSV = "apache_sample_1k.csv"

# %%
fs = s3fs.S3FileSystem(anon=True)

# %% [markdown]
# ## Download cyBERT Apache model from HuggingFace

# %%
if not path.exists(MODEL_FILENAME):
    fs = s3fs.S3FileSystem(anon=True)
    fs.get(HF_S3_BASE_PATH + "/" + MODEL_FILENAME, MODEL_FILENAME)

# %%
if not path.exists(CONFIG_FILENAME):
    fs = s3fs.S3FileSystem(anon=True)
    fs.get(HF_S3_BASE_PATH + "/" + CONFIG_FILENAME, CONFIG_FILENAME)

# %% [markdown]
# ## Load model into cyBERT

# %%
cybert = Cybert()
cybert.load_model(MODEL_FILENAME, CONFIG_FILENAME)

# %% [markdown]
# ## Download a sample of Apache logs

# %%
if not path.exists(APACHE_SAMPLE_CSV):
    fs = s3fs.S3FileSystem(anon=True)
    fs.get(CLX_S3_BASE_PATH + "/" + APACHE_SAMPLE_CSV, APACHE_SAMPLE_CSV)

# %%
logs_df = cudf.read_csv(APACHE_SAMPLE_CSV)

# %%
# Print raw logs
logs_df["raw"]
# Out:
# 0      [Sun Dec 04 20:22:49 2005] [notice] workerEnv....
# 1      193.106.31.130 - - [01/Sep/2019:03:28:00 +0200...
# 2      100.1.14.108 - - [29/Sep/2019:19:41:25 +0200] ...
# 3      13.84.43.203 - - [06/Nov/2019:03:15:15 +0100] ...
# 4      90.188.40.9 - - [18/Feb/2016:12:38:21 +0100] "...
#                              ...
# 995    154.0.14.250 - - [06/Dec/2016:16:59:06 +0100] ...
# 996    62.210.33.127 - - [20/Oct/2019:15:15:40 +0200]...
# 997    100.1.14.108 - - [04/Oct/2019:12:21:10 +0200] ...
# 998    198.50.156.189 - - [01/Apr/2017:19:47:53 +0200...
# 999    100.1.14.108 - - [23/Sep/2019:17:55:54 +0200] ...
# Name: raw, Length: 1000, dtype: object

# %% [markdown]
# ## Parse raw log data with cyBERT

# %%
parsed_df, confidence_df = cybert.inference(logs_df["raw"])
# Out:
# /opt/conda/envs/clx_dev/lib/python3.7/site-packages/cudf/core/subword_tokenizer.py:187: UserWarning: When truncation is not True, the behaviour currently differs from HuggingFace as cudf always returns overflowing tokens
#   warn(warning_msg)

# %%
parsed_df
# Out:
#                     time_received error_level  \
# 0      [Sun Dec 04 20:22:49 2005]    [notice]
# 1    [01/Sep/2019:03:28:00 +0200]         NaN
# 2    [29/Sep/2019:19:41:25 +0200]         NaN
# 3    [06/Nov/2019:03:15:15 +0100]         NaN
# 4    [18/Feb/2016:12:38:21 +0100]         NaN
# ..                            ...         ...
# 995  [06/Dec/2016:16:59:06 +0100]         NaN
# 996  [20/Oct/2019:15:15:40 +0200]         NaN
# 997  [04/Oct/2019:12:21:10 +0200]         NaN
# 998  [01/Apr/2017:19:47:53 +0200]         NaN
# 999  [23/Sep/2019:17:55:54 +0200]         NaN
#
#                                       error_message     remote_host  \
# 0    workerEnv.init () ok/etc/httpd/conf/workers2 .             NaN
# 1                                               NaN  193.106.31.130
# 2                                               NaN    100.1.14.108
# 3                                               NaN    13.84.43.203
# 4                                               NaN     90.188.40.9
# ..                                              ...             ...
# 995                                             NaN    154.0.14.250
# 996                                             NaN   62.210.33.127
# 997                                             NaN    100.1.14.108
# 998                                             NaN  198.50.156.189
# 999                                             NaN    100.1.14.108
#
#                                                  other request_method  \
# 0                                                  NaN            NaN
# 1                                                  ---           POST
# 2                                                  ---            GET
# 3                                                  ---            GET
# 4                                                  ---            GET
# ..                                                 ...            ...
# 995                                                - -           POST
# 996  --http://www.almhuette-raith.at/index.php.opti...            GET
# 997                                                ---            GET
# 998                                              --- -           POST
# 999                                                ---            GET
#
#                                            request_url request_http_ver  \
# 0                                                  NaN              NaN
# 1                             /administrator/index.php         HTTP/1.0
# 2                  /components/com.users/dispacher.php         HTTP/1.1
# 3                            //administrator/index.php         HTTP/1.1
# 4                                      /administrator/         HTTP/1.1
# ..                                                 ...              ...
# 995                           /administrator/index.php         HTTP/1.1
# 996   /images/stories/slideshow/almhuette.raith.06.jpg         HTTP/1.1
# 997  /modules/mod.bowslideshow/tmpl/js/sliderman.1....         HTTP/1.1
# 998                           /administrator/index.php         HTTP/1.1
# 999     /modules/mod.articles.categories/wp-xmlrpc.php         HTTP/1.1
#
#     status response_bytes_clf  \
# 0      NaN                NaN
# 1      200               4481
# 2      404                240
# 3      200               4270
# 4      200               4263
# ..     ...                ...
# 995    200               4263
# 996    200              68977
# 997    200              33472
# 998    200               4498
# 999    404                251
#
#                              request_header_user_agent  \
# 0                                                  NaN
# 1      Mozilla/4.0 (compatible.MSIE...; Windows NT...)
# 2                               python-requests/2.22.0
# 3    Mozilla/5.0 (Windows NT 10.0.Win64.x64.rv:65.0...
# 4    Mozilla/5.0 (Windows NT.. 1) AppleWebKit/537.3...
# ..                                                 ...
# 995  Mozilla/5.0 (Windows NT...; WOW64.rv:17.0) Gec...
# 996  Mozilla/5.0 (Macintosh.Intel Mac OS.10.14.5 )W...
# 997                                  Python-urllib/3.7
# 998                                                NaN
# 999                           Python/3.7 aiohttp/3.6.1
#
#                                 request_header_referer    X
# 0                                                  NaN  NaN
# 1                                                  NaN  NaN
# 2                                                  NaN  NaN
# 3                                                  NaN  NaN
# 4                                                  NaN  NaN
# ..                                                 ...  ...
# 995  http://almhuette-raith.at/administrator/index.php  NaN
# 996                                                NaN  NaN
# 997                                                NaN  NaN
# 998                                                NaN  NaN
# 999                                                NaN  NaN
#
# [1000 rows x 13 columns]
